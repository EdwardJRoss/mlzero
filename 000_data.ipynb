# %%
# default_exp data

# %% [markdown]
# Ideally the DATA_PATH would be configurable

# %%
#export
from pathlib import Path
import pickle
import pandas as pd
from urllib.request import urlretrieve
import urllib.parse
from tqdm.auto import tqdm

import typing as T

DATA_PATH = (Path.home() / ".cache") / "mlzero"

# %%
pd.options.display.max_columns = 200
pd.options.display.max_colwidth = 100
pd.options.display.html.use_mathjax = False

# %% [markdown]
# # Data Source Fetchers

# %% [markdown]
# ## Kaggle
#
# We don't use this in CI because it requires Kaggle Credentials, but is the original source of some datasets.
#
# Note we move the import to the function because even it will fail if there's not API credentials.

# %%
def fetch_from_kaggle(dataset: str, filename: str, data_path: Path = DATA_PATH, force: bool = False) -> pd.DataFrame:
    """Loads single dataset from Kaggle, downloading if necessary.
    Requires Kaggle API credentials: https://github.com/Kaggle/kaggle-api#api-credentials
    Intermediate files are stored in data_path.
    """
    from kaggle.api.kaggle_api_extended import KaggleApi
    dest = Path(data_path) / (urllib.parse.quote(filename) + '.zip')
    if force or not dest.exists():
        Path(data_path).mkdir(exist_ok=True, parents=True)
        kaggle = KaggleApi()
        kaggle.authenticate()
        kaggle.dataset_download_file(dataset, filename, path=data_path)
    return pd.read_csv(dest)

# %% [markdown]
# Progress Bar
# Taken from https://github.com/tqdm/tqdm/blob/master/examples/tqdm_wget.py

# %%
class TqdmUpTo(tqdm):
    """Alternative Class-based version of the above.
    Provides `update_to(n)` which uses `tqdm.update(delta_n)`.
    Inspired by [twine#242](https://github.com/pypa/twine/pull/242),
    [here](https://github.com/pypa/twine/commit/42e55e06).
    """

    def update_to(self, b=1, bsize=1, tsize=None):
        """
        b  : int, optional
            Number of blocks transferred so far [default: 1].
        bsize  : int, optional
            Size of each block (in tqdm units) [default: 1].
        tsize  : int, optional
            Total size (in tqdm units). If [default: None] remains unchanged.
        """
        if tsize is not None:
            self.total = tsize
        return self.update(b * bsize - self.n)  # also sets self.n = b * bsize

# %% [markdown]
# TODO: Don't allow partial/corrupted downloads

# %%
#export
def fetch_dataset(filename: str, data_path: Path = DATA_PATH, force: bool = False, data_loader=pd.read_csv) -> pd.DataFrame:
    """Loads a stored dataset, with  a progress bar"""
    dest = Path(data_path) / filename
    if force or not dest.exists():
        Path(data_path).mkdir(exist_ok=True, parents=True)
        url = f'https://skeptric.com/datasets/{filename}'
        with TqdmUpTo(unit='B', unit_scale=True, unit_divisor=1024, miniters=1, desc=filename) as t:
            urlretrieve(url, dest, reporthook=t.update_to)
    return data_loader(dest)

# %%
#export
def pickle_loader(filename):
    with open(filename, 'rb') as f:
        data = pickle.load(f)
    return data

# %% [markdown]
# # Text Data Sources

# %% [markdown]
# ## AU Jobs: Export this somewhere
#
# Data can be automatically extracted using [job-advert-analysis](https://github.com/EdwardJRoss/job-advert-analysis); just need somewhere suitable to store the output.

# %%
#export
def data_au_jobs(data_path: Path = DATA_PATH, force: bool = False) -> pd.DataFrame:
    """Gets Australian Job Ads
    
    License: CC BY-NC-SA 4.0
    See https://github.com/EdwardJRoss/job-advert-analysis
    """
    return fetch_dataset('au_jobs.pkl', data_path, force=force, data_loader=pickle_loader)

# %%
data_au_jobs()
# Out:
#                                                                                                  title  \
# 0                                                                            Outbound phone consultant
# 1                                                                                     Business Analyst
# 2                                             Senior Database Administrator - 3 month initial contract
# 3                                                                                       GIS Supervisor
# 4                                                                                      Project Manager
# ...                                                                                                ...
# 73421                                                                                   UX/UI Designer
# 73422                                  Membership of the Independent Metropolitan Water Advisory Panel
# 73423  Aboriginal Identified - Clerk General Scale - Cadetship Program - Various Locations - Temporary
# 73424                                                               Teacher Community Services, Orange
# 73425                                                        Community Members, Victims Advisory Board
#
#                                                                                                description  \
# 0      About the Role:\nDavidson are partnered with a client that have two upcoming campaigns requiring...
# 1      About the Company\nAre you ready to start your next challenge within one of the leading financia...
# 2      About the Company\nAn opportunity to join a leading organisation working as a Database Administr...
# 3      At Davidson our vision is quite simply to change the face of the human resources and recruitment...
# 4      The client is seeking an experienced Infrastructure Project Manager.\nThe successful candidate w...
# ...                                                                                                    ...
# 73421  Opportunity to design and deliver high quality user experience for MAAS online visitors\nTempora...
# 73422  EXPRESSIONS OF INTEREST FOR MEMBERSHIP OF THE INDEPENDENT METROPOLITAN WATER ADVISORY PANEL\nThe...
# 73423  ABOUT LEGAL AID NSW\nLegal Aid NSW is the largest legal aid agency in Australia, comprising of a...
# 73424  TAFE NSW Teacher – Community Services\n\nLocation: West Region, Orange\nPosition: Permanent Full...
# 73425  Community Members, Victims Advisory Board\nThe Attorney General is seeking nominations from elig...
#
#                                                                                                        uri  \
# 0                                https://www.davidsonwp.com/job/100562133233487/outbound-phone-consultant/
# 1                                      https://www.davidsonwp.com/job/100562133234964/business-analyst-16/
# 2                            https://www.davidsonwp.com/job/100562133234550/senior-database-administrator/
# 3                                           https://www.davidsonwp.com/job/100562133234519/gis-supervisor/
# 4                                       https://www.davidsonwp.com/job/100562133233911/project-manager-27/
# ...                                                                                                    ...
# 73421                                                https://iworkfor.nsw.gov.au/job/ux-ui-designer-213266
# 73422  https://iworkfor.nsw.gov.au/job/membership-of-the-independent-metropolitan-water-advisory-panel-...
# 73423  https://iworkfor.nsw.gov.au/job/aboriginal-identified-clerk-general-scale-cadetship-program-vari...
# 73424                             https://iworkfor.nsw.gov.au/job/teacher-community-services-orange-212294
# 73425                      https://iworkfor.nsw.gov.au/job/community-members-victims-advisory-board-213441
#
#                        view_date  \
# 0      2020-06-06 06:29:05+00:00
# 1      2020-06-03 00:11:31+00:00
# 2      2020-05-30 20:04:38+00:00
# 3      2020-06-06 07:00:26+00:00
# 4      2020-05-28 04:26:08+00:00
# ...                          ...
# 73421  2020-10-21 22:06:41+00:00
# 73422  2020-10-21 22:46:21+00:00
# 73423  2020-10-21 22:35:08+00:00
# 73424  2020-10-21 21:43:25+00:00
# 73425  2020-10-21 22:18:16+00:00
#
#                                                        org  \
# 0                                                 Davidson
# 1                                                 Davidson
# 2                                                 Davidson
# 3                                                 Davidson
# 4                                                 Davidson
# ...                                                    ...
# 73421  Trustees of the Museum of Applied Arts and Sciences
# 73422                                                Water
# 73423                  Legal Aid Commission, Office of the
# 73424                                             TAFE NSW
# 73425               Courts, Tribunals and Service Delivery
#
#                                                                                                 salary_raw  \
# 0                                                                                              Competitive
# 1                                                                                              Competitive
# 2                                                                                        $100000 per annum
# 3                                                                                $70000 - $81000 per annum
# 4                                                                                              Competitive
# ...                                                                                                    ...
# 73421  Salary package up to $119,200. Package includes salary ($97,152 - $107,541) employer's contribut...
# 73422                                                                                                    -
# 73423         • Salary package of up to $27,700 including study and book allowances for a 60-day placement
# 73424  $110,799 Package includes salary ($84,664 - $100,407), employer's contribution to superannuation...
# 73425
#
#        salary_min salary_max salary_hours  \
# 0             NaN        NaN          NaN
# 1             NaN        NaN          NaN
# 2        100000.0        NaN       2000.0
# 3         70000.0    81000.0       2000.0
# 4             NaN        NaN          NaN
# ...           ...        ...          ...
# 73421     97152.0   107541.0       2000.0
# 73422         NaN        NaN          NaN
# 73423     27700.0        NaN          8.0
# 73424     84664.0   100407.0       2000.0
# 73425         NaN        NaN          NaN
#
#                                      location_raw       loc_id loc_continent  \
# 0                                    Brisbane, AU  101934019.0       Oceania
# 1                                      Sydney, AU  101932003.0       Oceania
# 2                                   Melbourne, AU  101933229.0       Oceania
# 3                                   Moss Vale, AU  101939833.0       Oceania
# 4                                    Brisbane, AU  101934019.0       Oceania
# ...                                           ...          ...           ...
# 73421                 Sydney Region / Sydney City  101932003.0       Oceania
# 73422                 Sydney Region / Sydney City  101932003.0       Oceania
# 73423                               Sydney Region  101932003.0       Oceania
# 73424  Regional NSW / Bathurst & Central West NSW  102049305.0       Oceania
# 73425                 Sydney Region / Sydney City  101932003.0       Oceania
#
#       loc_country         loc_county loc_empire loc_localadmin   loc_locality  \
# 0       Australia           Brisbane  Australia  Brisbane City  Brisbane City
# 1       Australia             Sydney  Australia         Sydney         Sydney
# 2       Australia          Melbourne  Australia      Melbourne      Melbourne
# 3       Australia      Wingecarribee  Australia      Moss Vale      Moss Vale
# 4       Australia           Brisbane  Australia  Brisbane City  Brisbane City
# ...           ...                ...        ...            ...            ...
# 73421   Australia             Sydney  Australia         Sydney         Sydney
# 73422   Australia             Sydney  Australia         Sydney         Sydney
# 73423   Australia             Sydney  Australia         Sydney         Sydney
# 73424   Australia  Bathurst Regional  Australia           None           None
# 73425   Australia             Sydney  Australia         Sydney         Sydney
#
#           loc_macrocounty       loc_region    processor           source  \
# 0                Brisbane       Queensland   davidsonwp  CC-MAIN-2020-24
# 1                  Sydney  New South Wales   davidsonwp  CC-MAIN-2020-24
# 2               Melbourne         Victoria   davidsonwp  CC-MAIN-2020-24
# 3      Bowral - Mittagong  New South Wales   davidsonwp  CC-MAIN-2020-24
# 4                Brisbane       Queensland   davidsonwp  CC-MAIN-2020-24
# ...                   ...              ...          ...              ...
# 73421              Sydney  New South Wales  iworkfornsw  CC-MAIN-2020-45
# 73422              Sydney  New South Wales  iworkfornsw  CC-MAIN-2020-45
# 73423              Sydney  New South Wales  iworkfornsw  CC-MAIN-2020-45
# 73424                None  New South Wales  iworkfornsw  CC-MAIN-2020-45
# 73425              Sydney  New South Wales  iworkfornsw  CC-MAIN-2020-45
#
#       loc_neighbourhood  salary_valid salary_hours_inferred  salary_annual
# 0                  None         False                   NaN            NaN
# 1                  None         False                   NaN            NaN
# 2                  None          True                2000.0       100000.0
# 3                  None          True                2000.0        70000.0
# 4                  None         False                   NaN            NaN
# ...                 ...           ...                   ...            ...
# 73421               NaN          True                2000.0        97152.0
# 73422               NaN         False                   NaN            NaN
# 73423               NaN         False                   8.0            NaN
# 73424               NaN          True                2000.0        84664.0
# 73425               NaN         False                   NaN            NaN
#
# [73426 rows x 25 columns]

# %% [markdown]
# Should be quick on the second load

# %%
# %time data_au_jobs()
# Out:
# CPU times: user 732 ms, sys: 406 ms, total: 1.14 s
# Wall time: 1.18 s
#                                                                                                  title  \
# 0                                                                            Outbound phone consultant
# 1                                                                                     Business Analyst
# 2                                             Senior Database Administrator - 3 month initial contract
# 3                                                                                       GIS Supervisor
# 4                                                                                      Project Manager
# ...                                                                                                ...
# 73421                                                                                   UX/UI Designer
# 73422                                  Membership of the Independent Metropolitan Water Advisory Panel
# 73423  Aboriginal Identified - Clerk General Scale - Cadetship Program - Various Locations - Temporary
# 73424                                                               Teacher Community Services, Orange
# 73425                                                        Community Members, Victims Advisory Board
#
#                                                                                                description  \
# 0      About the Role:\nDavidson are partnered with a client that have two upcoming campaigns requiring...
# 1      About the Company\nAre you ready to start your next challenge within one of the leading financia...
# 2      About the Company\nAn opportunity to join a leading organisation working as a Database Administr...
# 3      At Davidson our vision is quite simply to change the face of the human resources and recruitment...
# 4      The client is seeking an experienced Infrastructure Project Manager.\nThe successful candidate w...
# ...                                                                                                    ...
# 73421  Opportunity to design and deliver high quality user experience for MAAS online visitors\nTempora...
# 73422  EXPRESSIONS OF INTEREST FOR MEMBERSHIP OF THE INDEPENDENT METROPOLITAN WATER ADVISORY PANEL\nThe...
# 73423  ABOUT LEGAL AID NSW\nLegal Aid NSW is the largest legal aid agency in Australia, comprising of a...
# 73424  TAFE NSW Teacher – Community Services\n\nLocation: West Region, Orange\nPosition: Permanent Full...
# 73425  Community Members, Victims Advisory Board\nThe Attorney General is seeking nominations from elig...
#
#                                                                                                        uri  \
# 0                                https://www.davidsonwp.com/job/100562133233487/outbound-phone-consultant/
# 1                                      https://www.davidsonwp.com/job/100562133234964/business-analyst-16/
# 2                            https://www.davidsonwp.com/job/100562133234550/senior-database-administrator/
# 3                                           https://www.davidsonwp.com/job/100562133234519/gis-supervisor/
# 4                                       https://www.davidsonwp.com/job/100562133233911/project-manager-27/
# ...                                                                                                    ...
# 73421                                                https://iworkfor.nsw.gov.au/job/ux-ui-designer-213266
# 73422  https://iworkfor.nsw.gov.au/job/membership-of-the-independent-metropolitan-water-advisory-panel-...
# 73423  https://iworkfor.nsw.gov.au/job/aboriginal-identified-clerk-general-scale-cadetship-program-vari...
# 73424                             https://iworkfor.nsw.gov.au/job/teacher-community-services-orange-212294
# 73425                      https://iworkfor.nsw.gov.au/job/community-members-victims-advisory-board-213441
#
#                        view_date  \
# 0      2020-06-06 06:29:05+00:00
# 1      2020-06-03 00:11:31+00:00
# 2      2020-05-30 20:04:38+00:00
# 3      2020-06-06 07:00:26+00:00
# 4      2020-05-28 04:26:08+00:00
# ...                          ...
# 73421  2020-10-21 22:06:41+00:00
# 73422  2020-10-21 22:46:21+00:00
# 73423  2020-10-21 22:35:08+00:00
# 73424  2020-10-21 21:43:25+00:00
# 73425  2020-10-21 22:18:16+00:00
#
#                                                        org  \
# 0                                                 Davidson
# 1                                                 Davidson
# 2                                                 Davidson
# 3                                                 Davidson
# 4                                                 Davidson
# ...                                                    ...
# 73421  Trustees of the Museum of Applied Arts and Sciences
# 73422                                                Water
# 73423                  Legal Aid Commission, Office of the
# 73424                                             TAFE NSW
# 73425               Courts, Tribunals and Service Delivery
#
#                                                                                                 salary_raw  \
# 0                                                                                              Competitive
# 1                                                                                              Competitive
# 2                                                                                        $100000 per annum
# 3                                                                                $70000 - $81000 per annum
# 4                                                                                              Competitive
# ...                                                                                                    ...
# 73421  Salary package up to $119,200. Package includes salary ($97,152 - $107,541) employer's contribut...
# 73422                                                                                                    -
# 73423         • Salary package of up to $27,700 including study and book allowances for a 60-day placement
# 73424  $110,799 Package includes salary ($84,664 - $100,407), employer's contribution to superannuation...
# 73425
#
#        salary_min salary_max salary_hours  \
# 0             NaN        NaN          NaN
# 1             NaN        NaN          NaN
# 2        100000.0        NaN       2000.0
# 3         70000.0    81000.0       2000.0
# 4             NaN        NaN          NaN
# ...           ...        ...          ...
# 73421     97152.0   107541.0       2000.0
# 73422         NaN        NaN          NaN
# 73423     27700.0        NaN          8.0
# 73424     84664.0   100407.0       2000.0
# 73425         NaN        NaN          NaN
#
#                                      location_raw       loc_id loc_continent  \
# 0                                    Brisbane, AU  101934019.0       Oceania
# 1                                      Sydney, AU  101932003.0       Oceania
# 2                                   Melbourne, AU  101933229.0       Oceania
# 3                                   Moss Vale, AU  101939833.0       Oceania
# 4                                    Brisbane, AU  101934019.0       Oceania
# ...                                           ...          ...           ...
# 73421                 Sydney Region / Sydney City  101932003.0       Oceania
# 73422                 Sydney Region / Sydney City  101932003.0       Oceania
# 73423                               Sydney Region  101932003.0       Oceania
# 73424  Regional NSW / Bathurst & Central West NSW  102049305.0       Oceania
# 73425                 Sydney Region / Sydney City  101932003.0       Oceania
#
#       loc_country         loc_county loc_empire loc_localadmin   loc_locality  \
# 0       Australia           Brisbane  Australia  Brisbane City  Brisbane City
# 1       Australia             Sydney  Australia         Sydney         Sydney
# 2       Australia          Melbourne  Australia      Melbourne      Melbourne
# 3       Australia      Wingecarribee  Australia      Moss Vale      Moss Vale
# 4       Australia           Brisbane  Australia  Brisbane City  Brisbane City
# ...           ...                ...        ...            ...            ...
# 73421   Australia             Sydney  Australia         Sydney         Sydney
# 73422   Australia             Sydney  Australia         Sydney         Sydney
# 73423   Australia             Sydney  Australia         Sydney         Sydney
# 73424   Australia  Bathurst Regional  Australia           None           None
# 73425   Australia             Sydney  Australia         Sydney         Sydney
#
#           loc_macrocounty       loc_region    processor           source  \
# 0                Brisbane       Queensland   davidsonwp  CC-MAIN-2020-24
# 1                  Sydney  New South Wales   davidsonwp  CC-MAIN-2020-24
# 2               Melbourne         Victoria   davidsonwp  CC-MAIN-2020-24
# 3      Bowral - Mittagong  New South Wales   davidsonwp  CC-MAIN-2020-24
# 4                Brisbane       Queensland   davidsonwp  CC-MAIN-2020-24
# ...                   ...              ...          ...              ...
# 73421              Sydney  New South Wales  iworkfornsw  CC-MAIN-2020-45
# 73422              Sydney  New South Wales  iworkfornsw  CC-MAIN-2020-45
# 73423              Sydney  New South Wales  iworkfornsw  CC-MAIN-2020-45
# 73424                None  New South Wales  iworkfornsw  CC-MAIN-2020-45
# 73425              Sydney  New South Wales  iworkfornsw  CC-MAIN-2020-45
#
#       loc_neighbourhood  salary_valid salary_hours_inferred  salary_annual
# 0                  None         False                   NaN            NaN
# 1                  None         False                   NaN            NaN
# 2                  None          True                2000.0       100000.0
# 3                  None          True                2000.0        70000.0
# 4                  None         False                   NaN            NaN
# ...                 ...           ...                   ...            ...
# 73421               NaN          True                2000.0        97152.0
# 73422               NaN         False                   NaN            NaN
# 73423               NaN         False                   8.0            NaN
# 73424               NaN          True                2000.0        84664.0
# 73425               NaN         False                   NaN            NaN
#
# [73426 rows x 25 columns]

# %% [markdown]
# ## Kaggle datasources
#
# The commands ending in `_kaggle` require [Kaggle's API Credentials](https://github.com/Kaggle/kaggle-api#api-credentials) to be set up.
# A mirror of the CC licenced data is provided without the `_kaggle` suffix.

# %% [markdown]
# ### [Wine Reviews](https://www.kaggle.com/zynicide/wine-reviews)
# CC BY-NC-SA 4.0

# %%
def data_wine_reviews_kaggle(data_path: Path = DATA_PATH, force: bool = False) -> pd.DataFrame:
    """Retrieves Wine Reivews Data
    
    Requires Kaggle Credentials
    
    License: CC BY-NC-SA 4.0
    See https://www.kaggle.com/zynicide/wine-reviews
    """
    return fetch_from_kaggle('zynicide/wine-reviews', 'winemag-data-130k-v2.csv', data_path=data_path)

# %%
#export
def data_wine_reviews(data_path: Path = DATA_PATH, force: bool = False) -> pd.DataFrame:
    """Retrieves Wine Reivews Data
    
    License: CC BY-NC-SA 4.0
    See https://www.kaggle.com/zynicide/wine-reviews
    """
    return fetch_dataset('winemag-data-130k-v2.csv.zip', data_path=data_path)

# %%
data_wine_reviews()
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                                                                                 description  \
# 0       Aromas include tropical fruit, broom, brimstone and dried herb. The palate isn't overly expressi...
# 1       This is ripe and fruity, a wine that is smooth while still structured. Firm tannins are filled o...
# 2       Tart and snappy, the flavors of lime flesh and rind dominate. Some green pineapple pokes through...
# 3       Pineapple rind, lemon pith and orange blossom start off the aromas. The palate is a bit more opu...
# 4       Much like the regular bottling from 2012, this comes across as rather rough and tannic, with rus...
# ...                                                                                                     ...
# 129966  Notes of honeysuckle and cantaloupe sweeten this deliciously feather-light spätlese. It's intens...
# 129967  Citation is given as much as a decade of bottle age prior to release, which means it is pre-cell...
# 129968  Well-drained gravel soil gives this wine its crisp and dry character. It is ripe and fruity, alt...
# 129969  A dry style of Pinot Gris, this is crisp with some acidity. It also has weight and a solid, powe...
# 129970  Big, rich and off-dry, this is powered by intense spiciness and rounded texture. Lychees dominat...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# 1                                     Avidagos      87   15.0
# 2                                          NaN      87   14.0
# 3                         Reserve Late Harvest      87   13.0
# 4           Vintner's Reserve Wild Child Block      87   65.0
# ...                                        ...     ...    ...
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0
# 129967                                     NaN      90   75.0
# 129968                                   Kritt      90   30.0
# 129969                                     NaN      90   32.0
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0
#
#                  province             region_1           region_2  \
# 0       Sicily & Sardinia                 Etna                NaN
# 1                   Douro                  NaN                NaN
# 2                  Oregon    Willamette Valley  Willamette Valley
# 3                Michigan  Lake Michigan Shore                NaN
# 4                  Oregon    Willamette Valley  Willamette Valley
# ...                   ...                  ...                ...
# 129966              Mosel                  NaN                NaN
# 129967             Oregon               Oregon       Oregon Other
# 129968             Alsace               Alsace                NaN
# 129969             Alsace               Alsace                NaN
# 129970             Alsace               Alsace                NaN
#
#                taster_name taster_twitter_handle  \
# 0            Kerin O’Keefe          @kerinokeefe
# 1               Roger Voss            @vossroger
# 2             Paul Gregutt           @paulgwine
# 3       Alexander Peartree                   NaN
# 4             Paul Gregutt           @paulgwine
# ...                    ...                   ...
# 129966  Anna Lee C. Iijima                   NaN
# 129967        Paul Gregutt           @paulgwine
# 129968          Roger Voss            @vossroger
# 129969          Roger Voss            @vossroger
# 129970          Roger Voss            @vossroger
#
#                                                                                                       title  \
# 0                                                                         Nicosia 2013 Vulkà Bianco  (Etna)
# 1                                                             Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2                                                             Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                                       St. Julian 2013 Reserve Late Harvest Riesling (Lake Michigan Shore)
# 4                       Sweet Cheeks 2012 Vintner's Reserve Wild Child Block Pinot Noir (Willamette Valley)
# ...                                                                                                     ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 Brauneberger Juffer-Sonnenuhr Spätlese Riesling (M...
# 129967                                                                    Citation 2004 Pinot Noir (Oregon)
# 129968                                                   Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)
# 129969                                                        Domaine Marcel Deiss 2012 Pinot Gris (Alsace)
# 129970                          Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caroline Gewurztraminer (Alsace)
#
#                variety                                    winery
# 0          White Blend                                   Nicosia
# 1       Portuguese Red                       Quinta dos Avidagos
# 2           Pinot Gris                                 Rainstorm
# 3             Riesling                                St. Julian
# 4           Pinot Noir                              Sweet Cheeks
# ...                ...                                       ...
# 129966        Riesling  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967      Pinot Noir                                  Citation
# 129968  Gewürztraminer                           Domaine Gresser
# 129969      Pinot Gris                      Domaine Marcel Deiss
# 129970  Gewürztraminer                          Domaine Schoffit
#
# [129971 rows x 14 columns]

# %% [markdown]
# ### [Movie Summaries from Wikipedia](https://www.kaggle.com/jrobischon/wikipedia-movie-plots)
# CC BY-SA 4.0

# %%
def data_wiki_movies_kaggle(data_path: Path = DATA_PATH, force:bool = False) -> pd.DataFrame:
    """Movie Summaries from Wikipedia
    
    Requires Kaggle Credentials
    
    License: CC BY-SA 4.0
    See https://www.kaggle.com/jrobischon/wikipedia-movie-plots
    """
    return fetch_from_kaggle('jrobischon/wikipedia-movie-plots', 'wiki_movie_plots_deduped.csv', data_path=data_path, force=force)

# %%
#export
def data_wiki_movies(data_path: Path = DATA_PATH, force:bool = False) -> pd.DataFrame:
    """Movie Summaries from Wikipedia
    
    License: CC BY-SA 4.0
    See https://www.kaggle.com/jrobischon/wikipedia-movie-plots
    """
    return fetch_dataset('wiki_movie_plots_deduped.csv.zip', data_path=data_path, force=force)

# %%
data_wiki_movies()
# Out:
# wiki_movie_plots_deduped.csv.zip: 0.00B [00:00, ?B/s]
#        Release Year                             Title Origin/Ethnicity  \
# 0              1901            Kansas Saloon Smashers         American
# 1              1901     Love by the Light of the Moon         American
# 2              1901           The Martyred Presidents         American
# 3              1901  Terrible Teddy, the Grizzly King         American
# 4              1902            Jack and the Beanstalk         American
# ...             ...                               ...              ...
# 34881          2014                 The Water Diviner          Turkish
# 34882          2017                Çalgı Çengi İkimiz          Turkish
# 34883          2017                      Olanlar Oldu          Turkish
# 34884          2017                  Non-Transferable          Turkish
# 34885          2017                İstanbul Kırmızısı          Turkish
#
#                                  Director  \
# 0                                 Unknown
# 1                                 Unknown
# 2                                 Unknown
# 3                                 Unknown
# 4      George S. Fleming, Edwin S. Porter
# ...                                   ...
# 34881             Director: Russell Crowe
# 34882                      Selçuk Aydemir
# 34883                         Hakan Algül
# 34884                     Brendan Bradley
# 34885                      Ferzan Özpetek
#
#                                                                                                       Cast  \
# 0                                                                                                      NaN
# 1                                                                                                      NaN
# 2                                                                                                      NaN
# 3                                                                                                      NaN
# 4                                                                                                      NaN
# ...                                                                                                    ...
# 34881  Director: Russell Crowe\n\nCast: Russell Crowe, Olga Kurylenko, Jai Courtney, Cem Yılmaz, Yılmaz...
# 34882                                                                            Ahmet Kural, Murat Cemcir
# 34883                                                                Ata Demirer, Tuvana Türkay, Ülkü Duru
# 34884                             YouTubers Shanna Malcolm, Shira Lazar, Sara Fletcher and Ashley Clements
# 34885                                            Halit Ergenç, Tuba Büyüküstün, Mehmet Günsür, Nejat İşler
#
#                  Genre  \
# 0              unknown
# 1              unknown
# 2              unknown
# 3              unknown
# 4              unknown
# ...                ...
# 34881          unknown
# 34882           comedy
# 34883           comedy
# 34884  romantic comedy
# 34885         romantic
#
#                                                                        Wiki Page  \
# 0                           https://en.wikipedia.org/wiki/Kansas_Saloon_Smashers
# 1                    https://en.wikipedia.org/wiki/Love_by_the_Light_of_the_Moon
# 2                          https://en.wikipedia.org/wiki/The_Martyred_Presidents
# 3                 https://en.wikipedia.org/wiki/Terrible_Teddy,_the_Grizzly_King
# 4               https://en.wikipedia.org/wiki/Jack_and_the_Beanstalk_(1902_film)
# ...                                                                          ...
# 34881                            https://en.wikipedia.org/wiki/The_Water_Diviner
# 34882       https://en.wikipedia.org/wiki/%C3%87alg%C4%B1_%C3%87engi_%C4%B0kimiz
# 34883                                 https://en.wikipedia.org/wiki/Olanlar_Oldu
# 34884                      https://en.wikipedia.org/wiki/Non-Transferable_(film)
# 34885  https://en.wikipedia.org/wiki/%C4%B0stanbul_K%C4%B1rm%C4%B1z%C4%B1s%C4%B1
#
#                                                                                                       Plot
# 0      A bartender is working at a saloon, serving drinks to customers. After he fills a stereotypicall...
# 1      The moon, painted with a smiling face hangs over a park at night. A young couple walking past a ...
# 2      The film, just over a minute long, is composed of two shots. In the first, a girl sits at the ba...
# 3      Lasting just 61 seconds and consisting of two shots, the first shot is set in a wood during wint...
# 4      The earliest known adaptation of the classic fairytale, this films shows Jack trading his cow fo...
# ...                                                                                                    ...
# 34881  The film begins in 1919, just after World War I has ended, and centres around Joshua Connor (Rus...
# 34882                          Two musicians, Salih and Gürkan, described the adventures of their cousins.
# 34883  Zafer, a sailor living with his mother Döndü in a coastal village in Izmir, has just separated f...
# 34884  The film centres around a young woman named Amy Tyler, who books a surprise holiday to Europe wi...
# 34885  The writer Orhan Şahin returns to İstanbul after so many years to help the well-known director D...
#
# [34886 rows x 8 columns]

# %% [markdown]
# ### [Womens Clothing E-Commerce Reviews](https://www.kaggle.com/nicapotato/womens-ecommerce-clothing-reviews)
# CC0

# %%
def data_women_clothing_reviews_kaggle(data_path: Path = DATA_PATH, force:bool = False) -> pd.DataFrame:
    """Women's E-commerce Clothing Reviews
    
    Requires Kaggle credentials
    
    License: CC0
    https://www.kaggle.com/nicapotato/womens-ecommerce-clothing-reviews
    """
    return fetch_from_kaggle('nicapotato/womens-ecommerce-clothing-reviews', 'Womens Clothing E-Commerce Reviews.csv', data_path, force=force)

# %%
#export
def data_women_clothing_reviews(data_path: Path = DATA_PATH, force:bool = False) -> pd.DataFrame:
    """Women's E-commerce Clothing Reviews
    
    License: CC0
    https://www.kaggle.com/nicapotato/womens-ecommerce-clothing-reviews
    """
    return fetch_dataset('Womens%20Clothing%20E-Commerce%20Reviews.csv.zip', data_path, force=force)

# %%
data_women_clothing_reviews()
# Out:
#        Unnamed: 0  Clothing ID  Age  \
# 0               0          767   33
# 1               1         1080   34
# 2               2         1077   60
# 3               3         1049   50
# 4               4          847   47
# ...           ...          ...  ...
# 23481       23481         1104   34
# 23482       23482          862   48
# 23483       23483         1104   31
# 23484       23484         1084   28
# 23485       23485         1104   52
#
#                                                     Title  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                 Some major design flaws
# 3                                        My favorite buy!
# 4                                        Flattering shirt
# ...                                                   ...
# 23481                      Great dress for many occasions
# 23482                          Wish it was made of cotton
# 23483                               Cute, but see through
# 23484  Very cute dress, perfect for summer parties and we
# 23485                     Please make more like this one!
#
#                                                                                                Review Text  \
# 0                                                    Absolutely wonderful - silky and sexy and comfortable
# 1      Love this dress!  it's sooo pretty.  i happened to find it in a store, and i'm glad i did bc i n...
# 2      I had such high hopes for this dress and really wanted it to work for me. i initially ordered th...
# 3      I love, love, love this jumpsuit. it's fun, flirty, and fabulous! every time i wear it, i get no...
# 4      This shirt is very flattering to all due to the adjustable front tie. it is the perfect length t...
# ...                                                                                                    ...
# 23481  I was very happy to snag this dress at such a great price! it's very easy to slip on and has a v...
# 23482  It reminds me of maternity clothes. soft, stretchy, shiny material. cut is flattering and drapes...
# 23483  This fit well, but the top was very see through. this never would have worked for me. i'm glad i...
# 23484  I bought this dress for a wedding i have this summer, and it's so cute. unfortunately the fit is...
# 23485  This dress in a lovely platinum is feminine and fits perfectly, easy to wear and comfy, too! hig...
#
#        Rating  Recommended IND  Positive Feedback Count   Division Name  \
# 0           4                1                        0       Initmates
# 1           5                1                        4         General
# 2           3                0                        0         General
# 3           5                1                        0  General Petite
# 4           5                1                        6         General
# ...       ...              ...                      ...             ...
# 23481       5                1                        0  General Petite
# 23482       3                1                        0  General Petite
# 23483       3                0                        1  General Petite
# 23484       3                1                        2         General
# 23485       5                1                       22  General Petite
#
#       Department Name Class Name
# 0            Intimate  Intimates
# 1             Dresses    Dresses
# 2             Dresses    Dresses
# 3             Bottoms      Pants
# 4                Tops    Blouses
# ...               ...        ...
# 23481         Dresses    Dresses
# 23482            Tops      Knits
# 23483         Dresses    Dresses
# 23484         Dresses    Dresses
# 23485         Dresses    Dresses
#
# [23486 rows x 11 columns]

# %% [markdown]
# ### [Tweets from AU 2019 election](https://www.kaggle.com/taniaj/australian-election-2019-tweets)
# CC0

# %%
def data_au_election_2019_tweets_kaggle(data_path: Path = DATA_PATH, force:bool = False) -> pd.DataFrame:
    """Tweets from the 2019 Australian Elections
    
    Collected from Twitter API keyword search betwen 2019-05-10 and 2019-05-20.
    
    Requires Kaggle credentials
    
    License: CC0: Public Domain
    See https://www.kaggle.com/taniaj/australian-election-2019-tweets
    """
    return fetch_from_kaggle('taniaj/australian-election-2019-tweets', 'auspol2019.csv', data_path, force=force)

# %%
#export
def data_au_election_2019_tweets(data_path: Path = DATA_PATH, force:bool = False) -> pd.DataFrame:
    """Tweets from the 2019 Australian Elections
    
    Collected from Twitter API keyword search betwen 2019-05-10 and 2019-05-20.
    
    License: CC0: Public Domain
    See https://www.kaggle.com/taniaj/australian-election-2019-tweets
    """
    return fetch_dataset('auspol2019.csv.zip', data_path, force=force)

# %%
data_au_election_2019_tweets()
# Out:
#                  created_at                   id  \
# 0       2019-05-20 09:13:44  1130401208756187136
# 1       2019-05-20 09:13:43  1130401205367140357
# 2       2019-05-20 09:13:33  1130401162782371841
# 3       2019-05-20 09:13:29  1130401143551434753
# 4       2019-05-20 09:13:23  1130401118666809345
# ...                     ...                  ...
# 183374  2019-05-11 03:19:57  1127050685621493760
# 183375  2019-05-11 02:50:09  1127043187292295169
# 183376  2019-05-11 02:31:09  1127038404066045952
# 183377  2019-05-11 00:01:33  1127000757717303296
# 183378  2019-05-10 21:14:17  1126958660544942085
#
#                                                                                                   full_text  \
# 0             After the climate election: shellshocked green groups remain resolute https://t.co/wyJzmAcyiD
# 1       @narendramodi @smritiirani Coverage of indian election on SBS tv channel, Australia. Jai hind 🇮🇳...
# 2       @workmanalice Do you know if Facebook is releasing an election post-mortem in Australia? They lo...
# 3       @vanbadham We all understand we have a compulsory preference system. Vote 1 mightn’t go to the m...
# 4       Shares were mixed in Asia, with India and Australia leading gains for the region following elect...
# ...                                                                                                     ...
# 183374  #australiavotes; The BANKS are taking your money and giving you a pittance in return. The Reserv...
# 183375     Vote casted.... So no democracy sausage for early voters? LOL! 😂 🤣 🌭 #australiavotes #auspol2019
# 183376  SINCERITY IS A #WINNING #SALES CHARACTERISTIC- #YOUR #PRIORITIES #ARE #CLEARLY #VISIBLE TO YOUR ...
# 183377  These arrived. No sign of a democracy sausage though. A true travesty if ever there was one. #au...
# 183378  #Robodebt - Ask ABC to ask the question - Will Labor stop Robodebt?\nI've submitted a question t...
#
#         retweet_count  favorite_count       user_id             user_name  \
# 0                 0.0             0.0  9.248486e+07          PIPELINEPETE
# 1                 0.0             0.0  7.756474e+08       Narinder Parmar
# 2                 0.0             0.0  5.687300e+04           Peter Wells
# 3                 0.0             0.0  9.081660e+17           The Realist
# 4                 0.0             0.0  5.260074e+08     Inquirer Business
# ...               ...             ...           ...                   ...
# 183374            0.0             0.0  1.010011e+18         ivanparty.org
# 183375            0.0             0.0  7.853301e+07         Ralph Michael
# 183376            0.0             0.0  1.009595e+18  LuceGluyas@gmail.com
# 183377            0.0             0.0  3.226870e+09          Sarah Hamlyn
# 183378            1.0             1.0  9.444655e+17      Tracey Hoolachan
#
#        user_screen_name  \
# 0              jocksjig
# 1           nparmar1957
# 2            peterwells
# 3         therealist822
# 4           InquirerBiz
# ...                 ...
# 183374       IvanpartyO
# 183375       OrangeRafi
# 183376       GluyasLuce
# 183377   in_deep_oceans
# 183378  democracydemon1
#
#                                                                                            user_description  \
# 0                                           Retired Tradesman and Progressive Anti Conservative!  Musician.
# 1       Life coach & trainer, Motivational speaker, Mater NLP Practitioner, Author, Fellow of Institute ...
# 2       Writes for @theage and @smh on technology and podcasts - works at Swinburne Uni as a Mac Admin -...
# 3       Calls it as I see it. Anti PC, SJW and VS. If you want to be warm and fuzzy, grab a blanket and ...
# 4                                  The official Twitter account of the Inquirer Group's business news team.
# ...                                                                                                     ...
# 183374  The IVAN PARTY is a new political party with a Royal solution to fix Australia and the United Ki...
# 183375  Filipino living in Australia|IT Pro|Traveler|otaku|I like a cars, kpop, anime and everything abo...
# 183376                                                                                                  NaN
# 183377  Nature lover, terrible photographer, marine scientist. 🇦🇺 Adelaide uni alum. Staff biologist @Mo...
# 183378  Pro justice, but hate the system. Straight, but pro lgbtiq. Christian, but definitely no saint. ...
#
#                      user_location      user_created_at
# 0             Brisbane, Queensland  2009-11-25 09:19:45
# 1       Wollongong, NSW, AUSTRALIA  2012-08-23 10:20:40
# 2                        Melbourne  2006-12-11 07:38:06
# 3                              NaN  2017-09-14 03:10:30
# 4                      Philippines  2012-03-16 03:51:59
# ...                            ...                  ...
# 183374                         NaN  2018-06-22 04:07:26
# 183375        Melbourne, Australia  2009-09-30 06:35:22
# 183376                         NaN  2018-06-21 00:32:35
# 183377                Key West, FL  2015-05-26 08:16:56
# 183378                   Australia  2017-12-23 07:11:25
#
# [183379 rows x 11 columns]

# %% [markdown]
# ### Unimplemented

# %% [markdown]
# Other interesting datasets (To consider):

# %% [markdown]
# https://www.kaggle.com/andrewmvd/okcupid-profiles
#
#
# CC0
# tboyle10/medicaltranscriptions mtsamples.csv
#
# https://www.kaggle.com/andrewmvd/okcupid-profiles/tboyle10/medicaltranscriptions

# %% [markdown]
# Enron Emails
# https://www.cs.cmu.edu/~./enron/
#
# https://www.kaggle.com/wcukierski/enron-email-dataset emails.csv

# %% [markdown]
# ## Gutenberg
#
# Texts from [Project Gutenberg](http://www.gutenberg.org/)

# %%
#export
from gutenberg.acquire import load_etext
from gutenberg.cleanup import strip_headers

# %%
#export
GUTENBERG_DICKENS = {
    98: 'A Tale of Two Cities',
    1400: 'Great Expectations',
    730: 'Oliver Twist',
    766: 'David Copperfield',
    19337: 'A Christmas Carol',
    786: 'Hard Times',
    1023: 'Bleak House',
    580: 'The Pickwick Papers',
    883: 'Out Mutual Friend',
    967: 'Nicholas Nickleby',
    700: 'The Old Curiosity Shop',
    821: 'Domeby and Son',
    963: 'Little Dorrit',
}

def data_dickens_corpus(data_path: Path = DATA_PATH, mirror:str="https://gutenberg.pglaf.org/") -> T.Dict[str, str]:
    """Download a corpus of Charles Dicken's most popular books
    
    data_path: Where to store the cache
    mirror   : Project Gutenberg mirror to use
    
    Returns a dictionary of {"title": "full text"}
    """
    dest = data_path / 'dickens.pkl'
    if not dest.exists():
        data = {title: strip_headers(load_etext(idx, mirror=mirror)).strip() for idx, title in GUTENBERG_DICKENS.items()}
        with open(dest, 'wb') as f:
            pickle.dump(data, f)
    with open(dest, 'rb') as f:
        data = pickle.load(f)
    return data

# %%
dickens = data_dickens_corpus()

# %% [markdown]
# This requires some more cleaning!

# %%
print(dickens['Great Expectations'][:1500])
# Out:
# [Illustration]
#
#
#
#
# Great Expectations
#
# [1867 Edition]
#
# by Charles Dickens
#
#
# Contents
#
#  Chapter I.
#  Chapter II.
#  Chapter III.
#  Chapter IV.
#  Chapter V.
#  Chapter VI.
#  Chapter VII.
#  Chapter VIII.
#  Chapter IX.
#  Chapter X.
#  Chapter XI.
#  Chapter XII.
#  Chapter XIII.
#  Chapter XIV.
#  Chapter XV.
#  Chapter XVI.
#  Chapter XVII.
#  Chapter XVIII.
#  Chapter XIX.
#  Chapter XX.
#  Chapter XXI.
#  Chapter XXII.
#  Chapter XXIII.
#  Chapter XXIV.
#  Chapter XXV.
#  Chapter XXVI.
#  Chapter XXVII.
#  Chapter XXVIII.
#  Chapter XXIX.
#  Chapter XXX.
#  Chapter XXXI.
#  Chapter XXXII.
#  Chapter XXXIII.
#  Chapter XXXIV.
#  Chapter XXXV.
#  Chapter XXXVI.
#  Chapter XXXVII.
#  Chapter XXXVIII.
#  Chapter XXXIX.
#  Chapter XL.
#  Chapter XLI.
#  Chapter XLII.
#  Chapter XLIII.
#  Chapter XLIV.
#  Chapter XLV.
#  Chapter XLVI.
#  Chapter XLVII.
#  Chapter XLVIII.
#  Chapter XLIX.
#  Chapter L.
#  Chapter LI.
#  Chapter LII.
#  Chapter LIII.
#  Chapter LIV.
#  Chapter LV.
#  Chapter LVI.
#  Chapter LVII.
#  Chapter LVIII.
#  Chapter LIX.
#
# [Illustration]
#
#
#
#
# Chapter I.
#
#
# My father’s family name being Pirrip, and my Christian name Philip, my
# infant tongue could make of both names nothing longer or more explicit
# than Pip. So, I called myself Pip, and came to be called Pip.
#
# I give Pirrip as my father’s family name, on the authority of his
# tombstone and my sister,—Mrs. Joe Gargery, who married the blacksmith.
# As I never saw my father or my mother, and never saw any likeness of
# either of them (for their days were long before the days of
# photographs), my first fancies regarding what they

# %%
#hide
from nbdev.export import notebook2script; notebook2script()
# Out:
# Converted 000_data.ipynb.
# Converted 00_core.ipynb.
# Converted 01_segment.ipynb.
# Converted 02_ngram.ipynb.
# Converted index.ipynb.
